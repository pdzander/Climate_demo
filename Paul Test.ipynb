# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gauss = np.random.rand(100)
plt.plot(gauss)

# %%
a=6
a
# Out:
# 6

# %% [markdown]
# # My Title
#
# ## Subtitle
#
# Normal text, not code. nothing fancy
